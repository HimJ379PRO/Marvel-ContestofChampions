# %% [markdown]
# <a href="https://colab.research.google.com/github/HimJ379PRO/Marvel-ContestofChampions/blob/main/Marvel_Contest_of_Champions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import modules
import gspread
from google.colab import auth, data_table
from google.auth import default

import pandas as pd

# Enable Interactive table
data_table.enable_dataframe_formatter()

# Authenticate and connect to Google Sheets
auth.authenticate_user()
creds, _ = default()
gc = gspread.authorize(creds)

# Open Google Sheet
mcoc_gsheet = "Marvel Contest of Champions"  # Replace with actual sheet name
spreadsheet = gc.open(mcoc_gsheet)

# Get all sheets
all_sheets = spreadsheet.worksheets()
selective_sheets = [sheet for sheet in all_sheets if sheet.title in ["Champs","Fav-Rec"]]

# Dictionary to store DataFrames
dfs = {}

# Loop through each sheet and convert to a DataFrame
for sheet in selective_sheets:
    sheet_title = sheet.title
    records = sheet.get_all_records()
    df = pd.DataFrame(records)
    dfs[sheet_title] = df  # Save DataFrame with sheet name as key

# %%
# Access DataFrame from a specific sheet by creating multiple df objects
champs_df = dfs["Champs"]
favRec_df = dfs["Fav-Rec"]

# %%
favRec_df.head(3)
# Out:
#   Id  Champ_Id            Champion   Class Acquired Favourite Recommended  \
# 0  1       231               Galan  Cosmic        5         1           0
# 1  2       188  Cosmic Ghost Rider  Cosmic        6         1           1
# 2  3       205            Hercules  Cosmic        6         1           1
#
#               Synergy Counter    BGs&AW Notes
# 0  Cosmic Ghost Rider              Both
# 1               Galan          Attacker
# 2                              Attacker

# %%
# Rename column to match the key columns
champs_df = champs_df.rename(columns={"Id":"Champ_Id"})

# %%
# Merge the dataframes
merged_df = pd.merge(champs_df,favRec_df)

merged_df.head(3)
# Out:
# Warning: Total number of columns (23) exceeds max_columns (20). Falling back to pandas display.
#    Champ_Id    Champion    Class  \
# 0        13      Gamora   Cosmic
# 1        23        Hulk  Science
# 2        25  Juggernaut   Mystic
#
#                                                  Bio  \
# 0  "The most dangerous woman in the galaxy" is a ...
# 1  PUNY HUMAN! Stop pestering Hulk with dumb ques...
# 2  Cain Marko was a bitter man with a big chip on...
#
#                                            Mechanics  \
# 0  Gamora is the Queen of stacking Buffs. Stack u...
# 1  Like with his original kit, Hulk is focused on...
# 2  Juggernaut is an unstoppable force, so stack y...
#
#                                      Basic Abilities Immunities Resistances  \
# 0     Fury, Cruelty, Bleed, Armor Break, True Strike
# 1  Poison Immunity, Fury, GAMMA RAGE, Physical Vu...
# 2  Crimson Gem of Cyttorak, Unstoppable, Unblocka...
#
#   Counters Weaknesses  ...                                             Fandom  \
# 0                      ...  https://marvel-contestofchampions.fandom.com/w...
# 1                      ...  https://marvel-contestofchampions.fandom.com/w...
# 2                      ...  https://marvel-contestofchampions.fandom.com/w...
#
#                                       Khonshu's Ankh  Id Acquired Favourite  \
# 0   https://khonshu-ankh.vercel.app/champions/gamora  57        6         1
# 1     https://khonshu-ankh.vercel.app/champions/hulk  10        6         1
# 2  https://khonshu-ankh.vercel.app/champions/jugg...  41        5         1
#
#   Recommended Synergy Counter    BGs&AW Notes
# 0           0
# 1           1                  Attacker
# 2           1                  Attacker
#
# [3 rows x 23 columns]

# %% [markdown]
# ## Damage Over Time Debuffs

# %%
bleed_champs_df = merged_df[merged_df['Basic Abilities'].str.contains('Bleed', case = 0, na = 0, regex=1)]

bleed_champs_df[['Champion','Basic Abilities','Immunities','Class','Acquired']]
# Out:
#                      Champion  \
# 0                      Gamora
# 5                     Magneto
# 6        Magneto (House of X)
# 7                       Venom
# 8                   Luke Cage
# 11  Black Panther (Civil War)
# 12               Nightcrawler
# 14                  Archangel
# 16                 Killmonger
# 21                     Domino
# 29                  Nick Fury
# 38                   Mole Man
# 39                     Terrax
# 42                 Hit-Monkey
# 45                 Apocalypse
# 46         Cosmic Ghost Rider
# 56                      Knull
# 57                     Sauron
# 59                  Black Cat
# 79                  Chee'ilth
# 81                   Bullseye
# 83                    Prowler
# 84                     Arcade
# 88                     Scream
# 90                 Arnim Zola
#
#                                       Basic Abilities         Immunities  \
# 0      Fury, Cruelty, Bleed, Armor Break, True Strike
# 5   Prowess, Bleed, Armor Break, Ability Accuracy ...
# 6                         Prowess, Armor Break, Bleed
# 7   Klyntar Mutation, Armor Break, Bleed, True Str...
# 8   Bleed Immunity, Resist Physical, Exhaustion, Stun              Bleed
# 11  Armor, Reflective Armor, Reflect Stun, Bleed, ...
# 12                      Evade, Precision, Bamf, Bleed
# 14                    Neurotoxin, Bleed, Poison, Stun
# 16  Armor, True Strike, Bleed, Unstoppable, Indest...
# 21              Luck, Critical Bleed, Critical Damage
# 29  Bleed, Internal Bleed, Unblockable, Fury's Fur...
# 38  Shock Immunity, True Accuracy, Bleed, Monster ...
# 39  Shock Immunity, Bleed Immunity, Power Cosmic, ...
# 42  Critical Bleed, Assassin's Cunning, Primal Rag...
# 45  Bleed, Weakness, Poison, Concussion, Degeneration
# 46  Bleed Immunity, Incinerate Immunity, Unblockab...  Bleed, Incinerate
# 56    Armor Break, True Accuracy, Degeneration, Bleed
# 57  Prowess, Unblockable, Bleed, Fury, Degeneratio...
# 59                 Bleed, Cruelty, Cleanse, Infuriate
# 79  Cleanse, Eagle’s Tranquilize, Grizzly’s Grit, ...
# 81  Cruelty, Bleed, Evade, Fury, True Accuracy, Im...
# 83  Rupture, Bleed-immunity, Incinerate-immunity, ...
# 84  Arcade Token, Auto-Block, Shock, Poisonous Clo...
# 88  Bleed, Armor Break, Madness Passives, Hybrid B...
# 90  Bleed Immunity, Poison Immunity, Special Lock,...
#
#       Class Acquired
# 0    Cosmic        6
# 5    Mutant        6
# 6    Mutant        5
# 7    Cosmic        6
# 8   Science        6
# 11    Skill
# 12   Mutant        6
# 14   Mutant        5
# 16    Skill
# 21   Mutant        6
# 29    Skill        6
# 38    Skill
# 39   Cosmic        6
# 42    Skill        6
# 45   Mutant
# 46   Cosmic        6
# 56   Cosmic        5
# 57   Mutant
# 59    Skill
# 79    Skill
# 81    Skill        6
# 83     Tech
# 84     Tech        6
# 88   Cosmic        6
# 90     Tech

# %% [markdown]
# ### Immunities

# %%
coldsnap_df = merged_df[merged_df['Basic Abilities'].str.contains('Coldsnap', case = 0, na = 0, regex=0) | merged_df['Immunities'].str.contains('Coldsnap', case = 0, na = 0, regex=0)]

coldsnap_df[['Champion','Basic Abilities','Immunities','Class','Acquired']]
# Out:
#            Champion                                    Basic Abilities  \
# 33  Elsa Bloodstone  Hellfire Rounds, Behemoth Busters, Precision, ...
# 71      Kate Bishop  Evade, Coldsnap, Tranquilize, Tracking, True A...
# 82      The Serpent  Coldsnap Immunity, Power Gain, Fear, Pierce, I...
#
#                 Immunities   Class Acquired
# 33  Debuffs (Non-Damaging)   Skill        6
# 71                           Skill
# 82                          Cosmic

# %% [markdown]
# ## Debuffs (Non-Damaging)

# %%
stun_df = merged_df[merged_df['Basic Abilities'].str.contains('Stun', case = 0, na = 0, regex=0)]

stun_df[['Champion','Basic Abilities','Immunities','Class','Acquired']]
# Out:
#                      Champion  \
# 4                  Hulkbuster
# 8                   Luke Cage
# 11  Black Panther (Civil War)
# 13                   Hyperion
# 14                  Archangel
# 25                      Thing
# 27            Mister Sinister
# 29                  Nick Fury
# 40               Red Guardian
# 44                  Sasquatch
# 49                  Shang-Chi
# 50               The Overseer
# 70           Ant-Man (Future)
# 72                    Shocker
# 73               Adam Warlock
#
#                                       Basic Abilities Immunities    Class  \
# 4           Armor Break, Stun, Power Burn, Power Lock                Tech
# 8   Bleed Immunity, Resist Physical, Exhaustion, Stun      Bleed  Science
# 11  Armor, Reflective Armor, Reflect Stun, Bleed, ...               Skill
# 13                Fury, Incinerate, Stun, Armor Break     Poison   Cosmic
# 14                    Neurotoxin, Bleed, Poison, Stun              Mutant
# 25                  Rock Stacks, Fury, Weakness, Stun             Science
# 27  Molecular Regeneration, Concussion, Stun, Powe...      Bleed   Mutant
# 29  Bleed, Internal Bleed, Unblockable, Fury's Fur...               Skill
# 40                  Stun, Trauma, Slow, Vulnerability             Science
# 44               Rupture, Stagger, Stun, Regeneration              Mystic
# 49        Slow, Cleanse, Unblockable, Stun, Precision               Skill
# 50              Gamma Power, Taunt, Stun, Disoriented             Science
# 70  Glancing, Power Detonation, Disintegrate, Armo...                Tech
# 72        Shock Immunity, Unblockable, Stun, Energize                Tech
# 73  Unblockable, True Damage, Precision, Fury, Sov...              Cosmic
#
#    Acquired
# 4         6
# 8         6
# 11
# 13        5
# 14        5
# 25        6
# 27        5
# 29        6
# 40        6
# 44        6
# 49
# 50        7
# 70        6
# 72
# 73

# %% [markdown]
# ### Immunities

# %%
psychic_shielding = merged_df[merged_df['Tags'].str.contains("Psychic Shielding", case = 0, na = 0)]

psychic_shielding[['Champion','Class','Basic Abilities','Tags']]
# Out:
#                 Champion   Class  \
# 2             Juggernaut  Mystic
# 5                Magneto  Mutant
# 6   Magneto (House of X)  Mutant
# 27       Mister Sinister  Mutant
# 80             Onslaught  Mutant
# 89        Jack O'Lantern    Tech
#
#                                       Basic Abilities  \
# 2   Crimson Gem of Cyttorak, Unstoppable, Unblocka...
# 5   Prowess, Bleed, Armor Break, Ability Accuracy ...
# 6                         Prowess, Armor Break, Bleed
# 27  Molecular Regeneration, Concussion, Stun, Powe...
# 80      Crush, Daunted, Neuroshock, Organic Magnetism
# 89    Plasma, Inflamed, Incinerate, Poison, Cowardice
#
#                                                  Tags
# 2   Defensive: Tank, Villain, Brotherhood of Mutan...
# 5   Offensive: Damage Over Time, Villain, Psychic ...
# 6   Offensive: Damage Over Time, Hero, Psychic Shi...
# 27  Control: Denial, Villain, Psychic Shielding, S...
# 80  Offensive: Damage Over Time, Defensive: Tank, ...
# 89  Offensive: Burst, Villain, Psychic Shielding, ...

# %%
unblockable_specials_champs_df = merged_df[merged_df['Basic Abilities'].str.contains("Unblockable", case = 0, na = 0)]

unblockable_specials_champs_df[['Champion','Basic Abilities','Immunities','Class','Acquired']]
# Out:
#               Champion                                    Basic Abilities  \
# 2           Juggernaut  Crimson Gem of Cyttorak, Unstoppable, Unblocka...
# 7                Venom  Klyntar Mutation, Armor Break, Bleed, True Str...
# 18              Bishop     Prowess, Regeneration, Unblockable, Incinerate
# 29           Nick Fury  Bleed, Internal Bleed, Unblockable, Fury's Fur...
# 35         Doctor Doom               Shock, Stagger, Unblockable, Nullify
# 36                Nova  Fury, Auto-Block, Nova Force, Unblockable, Ene...
# 46  Cosmic Ghost Rider  Bleed Immunity, Incinerate Immunity, Unblockab...
# 49           Shang-Chi        Slow, Cleanse, Unblockable, Stun, Precision
# 51            Hercules  Infuriate, True Sense, Precision, Cruelty, Imm...
# 57              Sauron  Prowess, Unblockable, Bleed, Fury, Degeneratio...
# 72             Shocker        Shock Immunity, Unblockable, Stun, Energize
# 73        Adam Warlock  Unblockable, True Damage, Precision, Fury, Sov...
# 76   Werewolf By Night  Rupture, Chilling Howl, Power Gain, Curse of L...
# 82         The Serpent  Coldsnap Immunity, Power Gain, Fear, Pierce, I...
# 87             Shathra  Energy Damage, Power Steal, Nullify, Atrophy, ...
#
#            Immunities   Class Acquired
# 2                      Mystic        5
# 7                      Cosmic        6
# 18                     Mutant        5
# 29                      Skill        6
# 35                     Mystic
# 36                     Cosmic        6
# 46  Bleed, Incinerate  Cosmic        6
# 49                      Skill
# 51    Stun, Death, KO  Cosmic        6
# 57                     Mutant
# 72                       Tech
# 73                     Cosmic
# 76                     Mystic
# 82                     Cosmic
# 87                     Mystic        6

# %%
armorUp_df = merged_df[merged_df['Basic Abilities'].str.contains("Armor", case = 0, na = 0) & (~merged_df['Basic Abilities'].str.contains("Armor Break", case=False, na=False, regex=False))]

armorUp_df[['Champion','Basic Abilities','Immunities','Class','Acquired']]
# Out:
#                      Champion  \
# 11  Black Panther (Civil War)
# 16                 Killmonger
# 31                    Warlock
# 34            Guillotine 2099
# 43                   Guardian
# 48                       Odin
# 58             Omega Sentinel
# 67                      Shuri
# 70           Ant-Man (Future)
#
#                                       Basic Abilities Immunities   Class  \
# 11  Armor, Reflective Armor, Reflect Stun, Bleed, ...              Skill
# 16  Armor, True Strike, Bleed, Unstoppable, Indest...              Skill
# 31    Armor, Virus Infection, Power Drain, Power Burn               Tech
# 34  Robotics, Self Repair, Digi-Souls, Armor, Pre-...               Tech
# 43           Armor, Force Field, Perfect Block, Taunt               Tech
# 48  Odinforce, Energize, Fury, Armor, True Strike,...             Cosmic
# 58  Self Repair, Pre-Fight Ability, Incinerate, Co...               Tech
# 67  Shock Immunity, Armor, Shock, Untouchable, Pre...               Tech
# 70  Glancing, Power Detonation, Disintegrate, Armo...               Tech
#
#    Acquired
# 11
# 16
# 31        6
# 34        5
# 43
# 48        6
# 58
# 67        6
# 70        6
